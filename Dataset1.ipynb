# %% [markdown]
# ### Create a random data set

# %%
import numpy as np
import random

# %%
x=np.random.rand(100)

# %%
f=10*x+5

# %%
array=x,f
array
# Out:
# (array([ 0.2924388 ,  0.90392446,  0.75797287,  0.22649357,  0.66434771,
#          0.89543988,  0.32024219,  0.14897825,  0.46680375,  0.55213333,
#          0.17248476,  0.89199669,  0.08150791,  0.62103735,  0.09900962,
#          0.29343801,  0.33879424,  0.58215679,  0.88267477,  0.54647445,
#          0.8695728 ,  0.86664289,  0.51555748,  0.56858363,  0.84016429,
#          0.96122966,  0.49404097,  0.68705651,  0.60159167,  0.83395959,
#          0.84421519,  0.18693278,  0.11692181,  0.60917714,  0.29439101,
#          0.20574251,  0.81735133,  0.31204062,  0.85716942,  0.04680973,
#          0.75405969,  0.36681631,  0.47444262,  0.33891136,  0.43103843,
#          0.3493482 ,  0.8475374 ,  0.47811689,  0.97301155,  0.69061716,
#          0.01026495,  0.60445691,  0.55888042,  0.24666106,  0.71239902,
#          0.56556013,  0.00664492,  0.64578686,  0.63478259,  0.02451328,
#          0.38006881,  0.67715187,  0.16255724,  0.85283924,  0.37950591,
# ...

# %%
np.savetxt("datos.txt", array)
